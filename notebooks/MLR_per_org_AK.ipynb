# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn
import scipy
import statsmodels.api as sm

from sklearn import linear_model

# %%
data = pd.read_csv('compiled_final_210308.csv')
df = pd.DataFrame(data)
df.head()
# Out:
#           GENENAME ORG  ENTREZID    LOG2FC
# 0  ABC_transporter  PA    879411 -0.038469
# 1  ABC_transporter  PA    883108 -0.207718
# 2  ABC_transporter  PA    878380 -0.187309
# 3  ABC_transporter  PA    880771  0.085173
# 4  ABC_transporter  PA    879023  0.038834

# %%
#feature_cols = ['GENENAME', 'ORG', 'LOG2FC']
#target_col = 'OUTPUT'

#model = mlr()
#model.fit_dataframe(X = feature_cols, y = target_col, dataframe = df)

# %%
# define data as pre-set feature names
model_features = df[['GENENAME', 'ORG']]

# convert to categorical values 
dummy_df = pd.get_dummies(df, columns=['GENENAME', 'ORG'])

# put target in another data frame
target = df[['LOG2FC']]

# %%
dummy_df.head()
list(dummy_df.columns) # missing column for BS?
# Out:
# ['REFSEQ',
#  'ENTREZID',
#  'LOG2FC',
#  'GENENAME_DNA_polymerase',
#  'GENENAME_NADH_NADPH',
#  'GENENAME_RNA_polymerase',
#  'GENENAME_cytochrome',
#  'GENENAME_efflux_transporter',
#  'GENENAME_electron_transfer',
#  'GENENAME_flagellar_motility',
#  'ORG_EC',
#  'ORG_PA']

# %%
X = dummy_df[['GENENAME_DNA_polymerase',
            'GENENAME_NADH_NADPH',
            'GENENAME_RNA_polymerase',
            'GENENAME_cytochrome',
            'GENENAME_efflux_transporter',
            'GENENAME_electron_transfer',
            'GENENAME_flagellar_motility',
            'ORG_EC',
            'ORG_PA', 
            'ORG_BS']]
y = df[['LOG2FC']]

# need to convert X to float using .astype
# model = (y, X.astype(float)).fit
# predictions = model.sm.predict(X)
# model.summary()

lm = linear_model.LinearRegression()
model = lm.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-592ded4152f9> in <module>
# ----> 1 X = dummy_df[['GENENAME_DNA_polymerase',
#       2             'GENENAME_NADH_NADPH',
#       3             'GENENAME_RNA_polymerase',
#       4             'GENENAME_cytochrome',
#       5             'GENENAME_efflux_transporter',
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1263             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1264
# -> 1265         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1266         return keyarr, indexer
#    1267
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1313             if raise_missing:
#    1314                 not_found = list(set(key) - set(ax))
# -> 1315                 raise KeyError(f"{not_found} not in index")
#    1316
#    1317             not_found = key[missing_mask]
#
# KeyError: "['ORG_BS'] not in index"

# %%
predictions = lm.predict(X)
print(predictions)[0:5]
# Out:
# [[ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [ 0.01017163]
#  [-0.20079771]
#  [-0.20079771]
#  [-0.20079771]
#  [-0.20079771]
#  [-0.20079771]
#  [-0.20079771]
#  [-0.20079771]
#  [-0.20079771]
#  [-0.20079771]
#  [-0.20079771]
#  [-0.20079771]
#  [-0.20079771]
#  [-0.20079771]
#  [-0.20079771]
#  [-0.20079771]
#  [-0.20079771]
#  [-0.19839743]
#  [-0.19839743]
#  [-0.00485982]
#  [-0.00485982]
#  [-0.00485982]
#  [-0.00485982]
#  [-0.00485982]
#  [-0.00485982]
#  [-0.00485982]
#  [-0.00485982]
#  [-0.00485982]
#  [-0.00485982]
#  [-0.00485982]
#  [-0.00485982]
#  [-0.00485982]
#  [-0.00485982]
#  [-0.00485982]
#  [-0.00485982]
#  [-0.00485982]
#  [-0.00485982]
#  [-0.00485982]
#  [-0.00485982]
#  [-0.00485982]
#  [-0.00485982]
#  [-0.00485982]
#  [-0.06208754]
#  [-0.06208754]
#  [-0.06208754]
#  [-0.06208754]
#  [-0.06208754]
#  [-0.06208754]
#  [-0.06208754]
#  [-0.06208754]
#  [-0.02268761]
#  [-0.02268761]
#  [-0.02268761]
#  [-0.02268761]
#  [-0.02268761]
#  [-0.08261165]
#  [-0.08261165]
#  [-0.08261165]
#  [-0.08261165]
#  [-0.08261165]
#  [-0.08261165]
#  [-0.08261165]
#  [-0.08261165]
#  [-0.08261165]
#  [-0.08261165]
#  [-0.08261165]
#  [-0.08261165]
#  [-0.12060291]
#  [-0.12060291]
#  [-0.12060291]
#  [-0.12060291]
#  [-0.12060291]
#  [-0.12060291]
#  [-0.12060291]
#  [ 0.06789052]
#  [ 0.06789052]
#  [ 0.06789052]
#  [ 0.06789052]
#  [ 0.06789052]
#  [-0.14307882]
#  [-0.14307882]
#  [-0.14307882]
#  [-0.14307882]
#  [-0.14307882]
#  [-0.14307882]
#  [-0.14307882]
#  [-0.14307882]
#  [-0.14307882]
#  [-0.14307882]
#  [-0.14307882]
#  [-0.14307882]
#  [-0.14307882]
#  [-0.14067854]
#  [-0.14067854]
#  [-0.14067854]
#  [-0.14067854]
#  [-0.14067854]
#  [-0.14067854]
#  [-0.14067854]
#  [-0.14067854]
#  [-0.14067854]
#  [-0.14067854]
#  [-0.14067854]
#  [ 0.05285907]
#  [ 0.05285907]
#  [ 0.05285907]
#  [ 0.05285907]
#  [ 0.05285907]
#  [ 0.05285907]
#  [ 0.05285907]
#  [ 0.05285907]
#  [ 0.05285907]
#  [ 0.05285907]
#  [ 0.05285907]
#  [ 0.05285907]
#  [ 0.05285907]
#  [ 0.05285907]
#  [ 0.05285907]
#  [ 0.05285907]
#  [ 0.05285907]
#  [ 0.05285907]
#  [ 0.05285907]
#  [-0.00436865]
#  [-0.00436865]
#  [-0.00436865]
#  [-0.00436865]
#  [-0.00436865]
#  [-0.00436865]
#  [-0.00436865]
#  [-0.00436865]
#  [-0.00436865]
#  [-0.00436865]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [ 0.03503129]
#  [-0.02489276]
#  [-0.02489276]
#  [-0.02489276]
#  [-0.02489276]
#  [-0.02489276]
#  [-0.02489276]
#  [-0.02489276]
#  [-0.02489276]
#  [-0.02489276]
#  [-0.02489276]
#  [-0.02489276]
#  [-0.02489276]
#  [-0.02489276]
#  [-0.02489276]
#  [-0.02489276]
#  [-0.02489276]
#  [-0.02489276]
#  [-0.02489276]
#  [-0.02489276]
#  [-0.02489276]
#  [-0.02489276]
#  [-0.02489276]
#  [-0.02489276]
#  [-0.02489276]
#  [-0.02489276]
#  [-0.06288402]
#  [-0.06288402]
#  [-0.06288402]
#  [-0.06288402]
#  [-0.06288402]
#  [-0.06288402]
#  [-0.06288402]
#  [-0.06288402]
#  [-0.06288402]
#  [-0.06288402]
#  [-0.06288402]
#  [-0.06288402]
#  [ 0.13433505]
#  [ 0.13433505]
#  [ 0.13433505]
#  [ 0.13433505]
#  [ 0.13433505]
#  [ 0.13433505]
#  [ 0.13433505]
#  [ 0.13433505]
#  [ 0.13433505]
#  [ 0.13433505]
#  [ 0.13433505]
#  [ 0.13433505]
#  [ 0.13433505]
#  [ 0.13433505]
#  [ 0.13433505]
#  [-0.07663429]
#  [-0.07663429]
#  [-0.07663429]
#  [-0.07663429]
#  [-0.07663429]
#  [-0.07663429]
#  [-0.07663429]
#  [-0.07663429]
#  [-0.07663429]
#  [-0.07663429]
#  [-0.07663429]
#  [-0.07663429]
#  [-0.07663429]
#  [-0.07663429]
#  [-0.07663429]
#  [-0.07663429]
#  [-0.07663429]
#  [-0.07663429]
#  [-0.07663429]
#  [-0.07423401]
#  [-0.07423401]
#  [-0.07423401]
#  [-0.07423401]
#  [-0.07423401]
#  [-0.07423401]
#  [-0.07423401]
#  [-0.07423401]
#  [-0.07423401]
#  [ 0.11930361]
#  [ 0.11930361]
#  [ 0.11930361]
#  [ 0.11930361]
#  [ 0.11930361]
#  [ 0.11930361]
#  [ 0.11930361]
#  [ 0.06207588]
#  [ 0.06207588]
#  [ 0.10147582]
#  [ 0.10147582]
#  [ 0.10147582]
#  [ 0.10147582]
#  [ 0.10147582]
#  [ 0.10147582]
#  [ 0.10147582]
#  [ 0.10147582]
#  [ 0.10147582]
#  [ 0.10147582]
#  [ 0.10147582]
#  [ 0.10147582]
#  [ 0.10147582]
#  [ 0.10147582]
#  [ 0.10147582]
#  [ 0.10147582]
#  [ 0.10147582]
#  [ 0.10147582]
#  [ 0.10147582]
#  [ 0.10147582]
#  [ 0.10147582]
#  [ 0.10147582]
#  [ 0.10147582]
#  [ 0.10147582]
#  [ 0.04155177]
#  [ 0.04155177]
#  [ 0.04155177]
#  [ 0.04155177]
#  [ 0.04155177]
#  [ 0.04155177]
#  [ 0.04155177]
#  [ 0.04155177]
#  [ 0.04155177]
#  [ 0.04155177]
#  [ 0.04155177]
#  [ 0.04155177]
#  [ 0.04155177]
#  [ 0.04155177]
#  [ 0.04155177]
#  [ 0.04155177]
#  [ 0.00356051]
#  [ 0.00356051]
#  [ 0.00356051]
#  [ 0.00356051]
#  [ 0.00356051]
#  [ 0.00356051]
#  [ 0.00356051]
#  [ 0.00356051]
#  [ 0.00356051]
#  [ 0.00356051]
#  [ 0.00356051]
#  [ 0.00356051]
#  [ 0.00356051]
#  [ 0.00356051]
#  [ 0.00356051]
#  [ 0.00356051]
#  [ 0.00356051]
#  [ 0.00356051]
#  [ 0.00356051]
#  [ 0.00356051]
#  [ 0.00356051]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-fa4e9040e769> in <module>
#       1 predictions = lm.predict(X)
# ----> 2 print(predictions)[0:5]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
lm.score(X, y)
# Out:
# 0.06538713704874188

# %%
X1 = dummy_df[['GENENAME_DNA_polymerase']]
y = df[['LOG2FC']]

lm = linear_model.LinearRegression()
model1 = lm.fit(X1, y)

# %%
predictions = lm.predict(X1)
print(predictions)[0:5]
# Out:
# [[-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.11874386]
#  [-0.11874386]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.11874386]
#  [-0.11874386]
#  [-0.11874386]
#  [-0.11874386]
#  [-0.11874386]
#  [-0.11874386]
#  [-0.11874386]
#  [-0.11874386]
#  [-0.11874386]
#  [-0.11874386]
#  [-0.11874386]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.11874386]
#  [-0.11874386]
#  [-0.11874386]
#  [-0.11874386]
#  [-0.11874386]
#  [-0.11874386]
#  [-0.11874386]
#  [-0.11874386]
#  [-0.11874386]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]
#  [-0.00124981]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-3d22de55545a> in <module>
#       1 predictions = lm.predict(X1)
# ----> 2 print(predictions)[0:5]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
lm.score(X1, y)
# Out:
# 0.007811356355964527
