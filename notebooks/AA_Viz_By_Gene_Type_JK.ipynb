# %% [markdown]
# # Amino Acid Grouping by Gene Type

# %%
# Imports

import math
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('compiled_features_complete.csv')
data
# Out:
#      Unnamed: 0         GENENAME ORG  ENTREZID     REFSEQ    LOG2FC  \
# 0             0  ABC_transporter  PA    879411  NP_248876 -0.038469
# 1             1  ABC_transporter  PA    883108  NP_248894 -0.207718
# 2             2  ABC_transporter  PA    878380  NP_249014 -0.187309
# 3             3  ABC_transporter  PA    880771  NP_249293  0.085173
# 4             4  ABC_transporter  PA    879023  NP_249295  0.038834
# ..          ...              ...  ..       ...        ...       ...
# 431         431   RNA_polymerase  BS    939937  NP_388354 -0.055848
# 432         432   RNA_polymerase  BS    936362  NP_391300 -0.140629
# 433         433   RNA_polymerase  BS    938729  NP_390226 -0.528350
# 434         434   RNA_polymerase  BS    939953  NP_389416  0.303125
# 435         435   RNA_polymerase  BS    939683  NP_389415 -0.083972
#
#       True_EID                                           SEQUENCE      AA_NP  \
# 0     15595384  mkaltssllglfaapvlagllgayvplasaappkeiriavpdvsag...  59.773371
# 1     15595400  mhqriasiglgltlalggsaqaagqlnvvswsgyfspqllekfeke...  54.941860
# 2     15595520  mtyrtpltllfaaglalggqaraegtlhfanwsdyyppellkkfek...  52.449568
# 3     15595799  mlpamrtgllcallgvtapawaeyvtvisfggankeaqetafykpf...  59.593023
# 4     15595801  mskslkaaslkfatlaaglacaaqamavdltvvsfgganksaqika...  54.310345
# ..         ...                                                ...        ...
# 431  728883360  mtqpskttkltkdevdrlisdyqtkqdeqaqetlvrvytnlvdmla...  42.748092
# 432  728886343  mdmklqqvqvlkpqltqelrqaitllgyhsaelaeyidelslenpl...  43.807339
# 433  728885268  mdvevkkngknaqlkdhevkelikqsqngdqqardllieknmrlvw...  43.137255
# 434  728884442  msrnkveicgvdtsklpvlkneemrklfrqlqdegddsareklvng...  45.384615
# 435  728884441  mkklklrlthlwykllmklglksdevyyiggsealppplskdeeqv...  47.280335
#
#         AA_POS     AA_POL     AA_NEG          MW      AROM     ISO_E
# 0    11.614731  17.847025  10.764873  37193.0756  0.070822  6.871061
# 1    11.337209  22.674419  11.046512  37859.8560  0.093023  6.033937
# 2    14.121037  20.461095  12.968300  38901.0268  0.112392  6.350359
# 3    11.918605  17.732558  10.755814  37832.8132  0.116279  6.919602
# 4    11.494253  22.413793  11.781609  38166.9526  0.112069  5.869103
# ..         ...        ...        ...         ...       ...       ...
# 431  16.030534  24.809160  16.412214  29900.8971  0.049618  5.545803
# 432  15.596330  27.752294  12.844037  49700.0669  0.064220  7.716086
# 433  16.862745  21.568627  18.431373  29372.0675  0.058824  5.252059
# 434  16.153846  21.923077  16.538462  30073.0463  0.061538  5.632312
# 435  17.573222  19.246862  15.899582  27652.0460  0.058577  8.725812
#
# [436 rows x 15 columns]

# %%
# Get column names
column_names = list(data.columns.values)

# %% [markdown]
# ### Sort data by gene type
# Types of genes are:
# - ABC_transporter
# - cytochrome
# - DNA_polymerase
# - efflux_transporter
# - electron_transfer
# - flagellar_motility
# - NADH_NADPH
# - RNA_polymerase

# %%
# Initialize dataframe

ABC_transporter_df = pd.DataFrame(columns=column_names)
cytochrome_df = pd.DataFrame(columns=column_names)
DNA_polymerase_df = pd.DataFrame(columns=column_names)
RNA_polymerase_df = pd.DataFrame(columns=column_names)
efflux_transporter_df = pd.DataFrame(columns=column_names)
electron_transfer_df = pd.DataFrame(columns=column_names)
flagellar_motility_df = pd.DataFrame(columns=column_names)
NADH_NADPH_df = pd.DataFrame(columns=column_names)

# %%
# Sort rows in data dataframe by gene name
for i in range(len(data)):
    if data['GENENAME'][i] == 'ABC_transporter':
        ABC_transporter_df.append(data.loc[i], ignore_index=True)
    elif data['GENENAME'][i] == 'cytochrome':
        cytochrome_df.append(data.loc[i], ignore_index=True)
    elif data['GENENAME'][i] == 'DNA_polymerase':
        DNA_polymerase_df.append(data.loc[i], ignore_index=True)
    elif data['GENENAME'][i] == 'RNA_polymerase':
        RNA_polymerase_df.append(data.loc[i], ignore_index=True)
    elif data['GENENAME'][i] == 'efflux_transporter':
        efflux_transporter_df.append(data.loc[i], ignore_index=True)
    elif data['GENENAME'][i] == 'electron_transfer':
        electron_transfer_df.append(data.loc[i], ignore_index=True)
    elif data['GENENAME'][i] == 'flagellar_motility':
        flagellar_motility_df.append(data.loc[i], ignore_index=True)
    elif data['GENENAME'][i] == 'NADH_NADPH':
        NADH_NADPH_df.append(data.loc[i], ignore_index=True)

# %%
ABC_transporter_df
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, GENENAME, ORG, ENTREZID, REFSEQ, LOG2FC, True_EID, SEQUENCE, AA_NP, AA_POS, AA_POL, AA_NEG, MW, AROM, ISO_E]
# Index: []

# %%
# List of dataframes
dfs = [ABC_transporter_df, cytochrome_df, DNA_polymerase_df, RNA_polymerase_df, 
       efflux_transporter_df, electron_transfer_df, flagellar_motility_df, NADH_NADPH_df]

# %%
# Determine average amino acid group percentages per gene type

nonpolar = []
positive = []
polar = []
negative = []

for i in range(len(dfs)):
    dat_frm = dfs[i]
    nonpolar.append(dat_frm['AA_NP'].mean())
    positive.append(dat_frm['AA_POS'].mean())
    polar.append(dat_frm['AA_POL'].mean())
    negative.append(dat_frm['AA_NEG'].mean())

# %%
dfs[i]['AA_NP']
# Out:
# Series([], Name: AA_NP, dtype: object)

# %% [markdown]
# ### Visualization function from Amino_Group_Scoring_JK notebook

# %%
def viz_aa_groups(nonpolar, positive, polar, negative):
    """
    Visualization for the amino acid groups in a sequence.  Inputs should be as a percentage.
    """
    
    labels = 'Nonpolar', 'Positive', 'Polar', 'Negative'
    sizes = [nonpolar, positive, polar, negative]
    fig, ax = plt.subplots()
    ax.pie(sizes, labels=labels, autopct='%1.0f%%', colors=['cornflowerblue', 'mediumaquamarine', 
                                                            'yellowgreen', 'palegoldenrod'])
    ax.axis('equal')
    plt.rcParams.update({'font.size': 14})
    plt.show()
    
    return fig

# %%
for i in range(len(dfs)):
    np = nonpolar[i]
    pos = positive[i]
    pol = polar[i]
    neg = negative[i]
    
    viz_aa_groups(np, pos, pol, neg)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-e8b5a9fd87d1> in <module>
#       5     neg = negative[i]
#       6
# ----> 7     viz_aa_groups(np, pos, pol, neg)
#
# <ipython-input-22-e04772369954> in viz_aa_groups(nonpolar, positive, polar, negative)
#       7     sizes = [nonpolar, positive, polar, negative]
#       8     fig, ax = plt.subplots()
# ----> 9     ax.pie(sizes, labels=labels, autopct='%1.0f%%', colors=['cornflowerblue', 'mediumaquamarine',
#      10                                                             'yellowgreen', 'palegoldenrod'])
#      11     ax.axis('equal')
#
# ~/miniconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/miniconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
#    3065             y += expl * math.sin(thetam)
#    3066
# -> 3067             w = mpatches.Wedge((x, y), radius, 360. * min(theta1, theta2),
#    3068                                360. * max(theta1, theta2),
#    3069                                facecolor=get_next_color(),
#
# ~/miniconda3/lib/python3.8/site-packages/matplotlib/patches.py in __init__(self, center, r, theta1, theta2, width, **kwargs)
#    1119         self.theta1, self.theta2 = theta1, theta2
#    1120         self._patch_transform = transforms.IdentityTransform()
# -> 1121         self._recompute_path()
#    1122
#    1123     def _recompute_path(self):
#
# ~/miniconda3/lib/python3.8/site-packages/matplotlib/patches.py in _recompute_path(self)
#    1131
#    1132         # Form the outer ring
# -> 1133         arc = Path.arc(theta1, theta2)
#    1134
#    1135         if self.width is not None:
#
# ~/miniconda3/lib/python3.8/site-packages/matplotlib/path.py in arc(cls, theta1, theta2, n, is_wedge)
#     916         # number of curve segments to make
#     917         if n is None:
# --> 918             n = int(2 ** np.ceil((eta2 - eta1) / halfpi))
#     919         if n < 1:
#     920             raise ValueError("n must be >= 1 or None")
#
# ValueError: cannot convert float NaN to integer
# posx and posy should be finite values
# posx and posy should be finite values
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/miniconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/miniconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/miniconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/miniconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2193                         self.figure.draw(renderer)
#    2194
# -> 2195                     bbox_inches = self.figure.get_tightbbox(
#    2196                         renderer, bbox_extra_artists=bbox_extra_artists)
#    2197                     if pad_inches is None:
#
# ~/miniconda3/lib/python3.8/site-packages/matplotlib/figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2504
#    2505         for a in artists:
# -> 2506             bbox = a.get_tightbbox(renderer)
#    2507             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    2508                 bb.append(bbox)
#
# ~/miniconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4200                     # this artist
#    4201                     continue
# -> 4202             bbox = a.get_tightbbox(renderer)
#    4203             if (bbox is not None
#    4204                     and 0 < bbox.width < np.inf
#
# ~/miniconda3/lib/python3.8/site-packages/matplotlib/artist.py in get_tightbbox(self, renderer)
#     276             The enclosing bounding box (in figure pixel coordinates).
#     277         """
# --> 278         bbox = self.get_window_extent(renderer)
#     279         if self.get_clip_on():
#     280             clip_box = self.get_clip_box()
#
# ~/miniconda3/lib/python3.8/site-packages/matplotlib/patches.py in get_window_extent(self, renderer)
#     596
#     597     def get_window_extent(self, renderer=None):
# --> 598         return self.get_path().get_extents(self.get_transform())
#     599
#     600     def _convert_xy_units(self, xy):
#
# ~/miniconda3/lib/python3.8/site-packages/matplotlib/path.py in get_extents(self, transform, **kwargs)
#     600                 # as can the ends of the curve
#     601                 xys.append(curve([0, *dzeros, 1]))
# --> 602             xys = np.concatenate(xys)
#     603         if len(xys):
#     604             return Bbox([xys.min(axis=0), xys.max(axis=0)])
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: need at least one array to concatenate
